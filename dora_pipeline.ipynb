# %% [markdown]
# ---
# title: "DoRA Replication Pipeline"
# format: ipynb
# jupyter: python3
# ---
#
# Mount google drive to load and save files

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

PROJECT_DIR = '/content/drive/MyDrive/CS4782/final'

os.chdir(PROJECT_DIR)
print(f"Current working directory set to: {os.getcwd()}")

# %% [markdown]
# Install the proper packages

# %%
# !pip install -r requirements.txt

# !pip install flash-attn --no-build-isolation

# %% [markdown]
# Paste the huggingface token when prompted

# %%
from huggingface_hub import notebook_login

notebook_login()

# %% [markdown]
# Run the train & eval pipeline

# %%
# remove the invisible Windows carriage returns (\r) from the file
# !sed -i 's/\r$//' run_experiments.sh

# Now add execution permissions and run it again!
# !chmod +x run_experiments.sh
# !./run_experiments.sh
